# %%
import pandas as pd
import numpy as np
import re

pd.options.display.max_columns = None

# %% [markdown]
# ### `Question-1:`
#
# The dataset is based on NFTs. This is quite large. So, when you will read the dataset, you have to wait. The link of the dataset: https://tinyurl.com/2pfhncqw
#
# Your task is to make a pivote table by using the columns "verification_status", "contract_type", "rarity_score" and "last_sale_price" to find out the total values.

# %%
# code here
data = pd.read_csv('./datasets/dataset_task_22/nfts_train - nfts_train.csv')

# %%
data.drop(columns = 'Unnamed: 0',inplace = True)

# %%
data.head(2)
# Out:
#    rarity_score last_sale_date  last_sale_price  total_supply creation_date  \
# 0      2.000000        2022-11         1.266732             1       2022-04
# 1     97.077216        2021-08         1.200357          8888       2021-07
#
#   verification_status  n_of_traits contract_type  seller_fees  platform_fees  \
# 0            verified            2           own       1000.0            250
# 1            verified            5           own        500.0            250
#
#    openrarity_enabled  has_website  has_own_twitter  has_discord  has_medium  \
# 0               False        False             True         True       False
# 1               False        False             True         True       False
#
#    n_tweets_in_range   avg_likes  avg_replies  avg_retweets  min_likes  \
# 0                 31  187.967742     8.290323     60.935484          0
# 1                 11  133.181818    13.454545     55.181818          0
#
#    min_replies  min_retweets  max_likes  max_replies  max_retweets
# 0            0             2        591           28           380
# 1            0             7        402           47           239

# %%
data.pivot_table(index = ['verification_status'],columns =['contract_type'],values = ['rarity_score','last_sale_price'],aggfunc = 'sum')
# Out:
#                     last_sale_price                 rarity_score
# contract_type               default            own       default           own
# verification_status
# approved                 658.931935    1684.819488  3.973082e+08  3.929607e+06
# verified                 370.304092  667394.862655  2.475007e+06  4.165654e+07

# %% [markdown]
# ### `Question-2:`
#
# You are given a dataset about the cars' price and miles driven of different cars throughout the different years. The link of the dataset: https://tinyurl.com/2r24n45l. Your tasks are
# - make a pivot table of the brands (the required brands are given below) from the "Year" 2018 to the year 2022 in which the "Price" is shown as average values and "Miles" are in median values. In this pivote table, every row represents a particular brand and each column represents either average "Price" of a partucular year or median values of "Miles" of a particular year.
# - At the end plot a kde chart for the "Price" and "Miles" by using your pivot table.
#
# There are some challenges to solve this task:
# - There is no column that is represented to the brand name of the car. You have to find out on your own.
# - Some values of "Years" column are misleading. You have to reset this column too that every value should tell a valid meaning.

# %%
# code her
data2 = pd.read_csv('https://tinyurl.com/2r24n45l')

# %%
data2['Year'] = data2['Year'].astype(str)

# %%
data2[data2['Year'].apply(lambda ele:len(ele)>4)]['Year'].str[:4]
# Out:
# 4        2017
# 31       2019
# 34       2016
# 39       2013
# 46       2013
#          ...
# 21952    2015
# 21963    2016
# 21970    2012
# 21975    2015
# 21981    2015
# Name: Year, Length: 2851, dtype: object

# %%
data2['Year']=data2['Year'].apply(lambda ele:ele[:4] if len(ele)>4 else ele)

# %%
data2['Year'].unique()
# Out:
# array(['2018', '2020', '2012', '2019', '2017', '2016', '2015', '2014',
#        '2010', '2013', '2011', '2021', '2022', '2009', '2023'],
#       dtype=object)

# %%
data2['brand'] = data2['Name'].str.split().str.get(0)

# %%
temp = data2[data2['Year'].isin(['2018','2019','2020','2021','2022'])]

# %%
temp
# Out:
#                            Name  Year  Miles  Price       brand
# 0                Chevrolet Trax  2018  41946  16990   Chevrolet
# 1                   GMC Terrain  2020  45328  23990         GMC
# 3                 Jeep Renegade  2019  35372  21590        Jeep
# 5                  Buick Encore  2019  47973  18590       Buick
# 24     Mitsubishi Eclipse Cross  2018  85475  16990  Mitsubishi
# ...                         ...   ...    ...    ...         ...
# 21976             Jeep Renegade  2020  63054  20590        Jeep
# 21978              Nissan Versa  2022   9975  22990      Nissan
# 21982             Nissan Murano  2019  38638  24990      Nissan
# 21987         Volkswagen Tiguan  2019  42636  24990  Volkswagen
# 21998  Toyota Corolla Hatchback  2020  27945  23990      Toyota
#
# [7492 rows x 5 columns]

# %%
final_df = temp.pivot_table(index = 'brand', columns = 'Year',aggfunc = {'Miles':'median','Price':'mean'})

# %%
final_df['Price'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
final_df['Miles'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ### `Question-3:`
#
# You are given a dataset of **Daily Power Generation in India** of regional wise of all Power Stations. Link of the dataset: https://tinyurl.com/2nq6kugt
#
# Task
# - In this dataset, there are many columns. Two of them are `Actual(MU)` and `Excess(+) / Shortfall (-)`. `Actual(MU)` represents the actual power generation. `Excess(+) / Shortfall (-)` tells is that generated power is excess or shortfall for that particular day of a power station. You have to find out what should be the actual power generation required for that day by the power stations that there would not be any excess or shorfall power. For the result, make a new column.
# - Find out the month of the day and store it as a new column.
# - Find out top 10 frequently appeared power stations in this dataframe.
# - Next create a pivot table of which every row represents a power station and every column represents a month in a order. Like January, February, March...
# - It is hard to get inside if you look through the only pivot table. So plot the pivot table.

# %%
# code here
data3 = pd.read_csv('https://tinyurl.com/2nq6kugt')
data3.head()
# Out:
#         Dates      Power Station  Monitored Cap.(MW)  \
# 0  2017-09-01              Delhi              2235.4
# 1  2017-09-01            Haryana              2720.0
# 2  2017-09-01   Himachal Pradesh              3378.0
# 3  2017-09-01  Jammu and Kashmir              1285.0
# 4  2017-09-01             Punjab              3826.3
#
#    Total Cap. Under Maintenace (MW)  Planned Maintanence (MW)  \
# 0                            135.00                      0.00
# 1                           2470.00                      0.00
# 2                            379.00                      0.00
# 3                            150.00                      0.00
# 4                           2697.65                     77.65
#
#    Forced Maintanence(MW)  Other Reasons (MW)  Programme or Expected(MU)  \
# 0                   135.0                   0                         13
# 1                  2470.0                   0                         28
# 2                   231.0                   0                         40
# 3                     0.0                   0                         14
# 4                  2620.0                   0                         39
#
#    Actual(MU)  Excess(+) / Shortfall (-)  Deviation
# 0          18                       5.00        0.0
# 1           7                     -21.80        0.0
# 2          46                       5.63        0.0
# 3          23                       9.43        0.0
# 4          17                     -21.69        0.0

# %%
temp1 = data3.pivot_table(index = 'Dates',values = ['Actual(MU)','Excess(+) / Shortfall (-)'],aggfunc = 'sum')
temp1['result'] = temp1['Actual(MU)']- (temp1['Excess(+) / Shortfall (-)'])
temp1
# Out:
#             Actual(MU)  Excess(+) / Shortfall (-)   result
# Dates
# 2017-09-01        3063                    -344.17  3407.17
# 2017-09-02        3095                    -312.12  3407.12
# 2017-09-03        3044                    -364.44  3408.44
# 2017-09-04        3251                    -151.46  3402.46
# 2017-09-05        3283                    -129.28  3412.28
# ...                ...                        ...      ...
# 2022-12-18        3573                     -59.35  3632.35
# 2022-12-19        3724                      86.60  3637.40
# 2022-12-20        3755                     123.57  3631.43
# 2022-12-21        3765                     111.99  3653.01
# 2022-12-22        3783                     132.09  3650.91
#
# [1857 rows x 3 columns]

# %%
# ii)
data3['Dates'] = pd.to_datetime(data3['Dates'])

# %%
data3['Months'] = data3['Dates'].dt.month_name()
data3['Months']
# Out:
# 0         September
# 1         September
# 2         September
# 3         September
# 4         September
#             ...
# 345268        April
# 345269        April
# 345270        April
# 345271        April
# 345272        April
# Name: Months, Length: 345273, dtype: object

# %%
# iii)
top_10 = data3['Power Station'].value_counts().head(10).index.to_list()

# %%
top_10_df = data3[data3['Power Station'].isin(top_10)]

# %%
top_10_df['Months'] = top_10_df['Months'].sort_values()
# Out:
# C:\Users\Kragon\AppData\Local\Temp\ipykernel_22968\385100781.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_10_df['Months'] = top_10_df['Months'].sort_values()

# %%
final_df = top_10_df.pivot_table(index = 'Months',columns = 'Power Station',aggfunc = 'sum')
final_df.sort_values(by = 'Months')
# Out:
# C:\Users\Kragon\AppData\Local\Temp\ipykernel_22968\1038724136.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   final_df = top_10_df.pivot_table(index = 'Months',columns = 'Power Station',aggfunc = 'sum')
#               Actual(MU)                                                   \
# Power Station        APL GMR ENERG IBPIL JPPVL JSWEL   NHPC    NLC  NPCIL
# Months
# April              17446      3724     0  4254  3106   7883   7177  12989
# August             19558      3859     0  5246  3531  16431   7571  16752
# December           24951      4910     0  4876  3701   4897   8971  21072
# February           18784      3830     0  3533  3052   4233   8549  15393
# January            21617      4269     0  4006  3709   3981   8682  17214
# July               19657      4056     0  5122  3453  16679   7956  18128
# June               18858      4259     0  6088  3523  14809   8600  18299
# March              30425      6200     0  5926  5218   9899  12706  25745
# May                15636      3891     0  4673  3420  10414   7074  13954
# November           24616      5459     0  5475  3921   6636   8893  21407
# October            23790      4534     0  5595  4705   9308   8520  19621
# September          24152      4389     0  6735  4459  15876   9371  19836
#
#                                  Deviation                                   \
# Power Station NTPC Ltd. TATA PCL       APL GMR ENERG IBPIL   JPPVL    JSWEL
# Months
# April            101832     2657   -160.41   -154.01   0.0  343.45  1149.37
# August           115426     2674      0.00      0.00   0.0    0.00     0.00
# December         130939     3025   -675.06     10.91   0.0   45.78  -748.77
# February         111891     2533      0.00      0.00   0.0    0.00     0.00
# January          119130     2511      0.00      0.00   0.0    0.00     0.00
# July             116488     2618      0.00      0.00   0.0    0.00     0.00
# June             114132     2959      0.00      0.00   0.0    0.00     0.00
# Months
# April           6270   5139   9666     62667     1830
# August         13144   6651  14546     85944     2353
# December        3937   8233  17935    106870     2681
# February        4508   8624  15891    103783     2610
# January         3658   9201  17733    111787     2613
# July           13454   6417  13762     85112     2450
# June           12180   6084  13664     86032     2490
# March           8951  11160  23795    139251     3881
# May             8401   5095  10051     66922     1891
# November        5336   7825  17602    101689     2884
# October         7630   6965  14996     93873     2667
# September      13262   8157  16956    100961     3000
#
#               Total Cap. Under Maintenace (MW)                               \
# Power Station                              APL GMR ENERG     IBPIL    JPPVL
# Months
# April                                 273570.0   48150.0   78000.0  13970.0
# August                                425370.0   91550.0  100750.0  69310.0
# December                              409860.0   76990.0  115050.0  47060.0
# February                              366300.0   74970.0   91650.0  45040.0
# January                               351780.0   77690.0  100750.0  41000.0
# July                                  407550.0   73380.0  100100.0  80010.0
# June                                  438570.0   59000.0   97500.0  14100.0
# March                                 510510.0   93180.0  139100.0  42130.0
# May                                   377190.0   44080.0   80600.0  14350.0
# November                              430650.0   60095.0  116350.0  17810.0
# October                               371580.0   68025.0  107250.0  29280.0
# September                             437910.0  107400.0  113100.0  54680.0
#
#
# Power Station     JSWEL      NHPC       NLC     NPCIL   NTPC Ltd. TATA PCL
# Months
# April           57310.0   94217.6   73500.0  222880.0  1063130.01  34580.0
# August          93650.0  106970.8  160545.0  294440.0  1952343.30  47740.0
# December       104660.0  274196.8  151330.0  261600.0  2071611.40  51610.0
# February        88500.0  214282.6   64055.0  274000.0  1331346.49  46140.0
# January         82600.0  251921.0   93045.0  283080.0  1459832.01  63850.0
# July            96360.0   94111.6  143640.0  215640.0  1779959.26  48610.0
# June            86230.0  107288.6  107375.0  182080.0  1841203.47  42280.0
# March          132590.0  258336.2  156755.0  296520.0  2020162.08  43700.0
# May             51300.0   98409.8   85305.0  198000.0  1370584.54  35530.0
# November        96640.0  188684.4  157105.0  247960.0  2226625.84  40390.0
# October         57850.0  139268.6  132245.0  220920.0  2006349.61  35180.0
# September       84980.0  137327.2  149900.0  288400.0  1883629.52  51160.0

# %%
final_df.plot(kind = 'line')
# Out:
# <Axes: xlabel='Months'>

# %% [markdown]
# ###`Q-4` You are given a file `question-answer.csv`. Your task is to make a dataframe from it with two columns - `question` and `answers`.
#
# * Questions in the file start from `Q<number>`; E.g.  `Q1` denotes question no. `1`
# * Answers starts from `Ans<number>`; Eg. `Ans1` denotes answer of question no `1`
# * MAke sure you look at columns name carefully
#
# CSV File - "https://drive.google.com/file/d/10rmV3XrVtzpDTtYZF3UtCdcU0ajBJjGY/view?usp=share_link"

# %%
# code here
ques4 = pd.read_csv('./datasets/dataset_task_22/question-answer.csv')
ques4.head()
# Out:
#    Unnamed: 0                                                  2
# 0           0                           Q1-What is Data Science?
# 1           1  Ans1-Data Science combines statistics, maths, ...
# 2           2             Q2-2. How is logistic regression done?
# 3           3  Ans2-Logistic regression measures the relation...
# 4           4         Q3-How do you build a random forest model?

# %%
ques_df = ques4[ques4['2'].str.startswith('Q')]['2'].str.split('-').str.get(1).reset_index()

# %%
ans_df = ques4[ques4['2'].str.startswith('Ans')]['2'].str.split('-').str.get(1).reset_index()

# %%
final = ques_df.merge(ans_df,left_index = True, right_index = True).drop(columns = ['index_x','index_y']).rename(columns= {'2_x':'Questions','2_y':'Answers'})

# %% [markdown]
# ###`Q-5`: Print Question and answer of those questions which does not contains any question mark (`?`).

# %%
# code here
final['Questions'].str.endswith('?')
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True
# Name: Questions, dtype: bool

# %% [markdown]
# ###`Q 6-10` LOG and EMPLOYEE
# 6. Show `activity` details month wise. Show count for each `activity`
# 7. Find employee who did most `activity` in January month.
# 8. Employee who have worked most no of times on Weekends.
# 9. Which activity is logged most on buisness days.
# 10. Week Days wise activity table.
# ```
# log_file = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vT-OMrmmNdOTM-B5f5F1EpCutMVG230UZiLvqlsg0NIKUKR3yrqiI2r1pEX-LvSEk-3WwySPYtvbBC-/pub?gid=1937029224&single=true&output=csv")
# employee = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vQ5AuFqRjSZVBKm5zyDxquX6utubq1DJKkYDI70vjeidAnyAu70KMSYpMYzeVSNVTeUIJBpfF6jU5E6/pub?gid=798824749&single=true&output=csv")
#
# ```
#
# Note(for common field):- Employee file has `EMPLOYEE_ID` and LOG file has `emp_id`

# %%
# code here
log_file = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vT-OMrmmNdOTM-B5f5F1EpCutMVG230UZiLvqlsg0NIKUKR3yrqiI2r1pEX-LvSEk-3WwySPYtvbBC-/pub?gid=1937029224&single=true&output=csv")
employee = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vQ5AuFqRjSZVBKm5zyDxquX6utubq1DJKkYDI70vjeidAnyAu70KMSYpMYzeVSNVTeUIJBpfF6jU5E6/pub?gid=798824749&single=true&output=csv")

# %%
log_file.head(2)
# Out:
#    Log_ID          dt   dept  emp_id  activity       eqpt
# 0    1000  2022-01-07  Dept6     115  Cleaning        UPS
# 1    1001  2022-01-08  Dept4     105  Cleaning  Generator

# %%
employee.head(2)
# Out:
#    EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL
# 0          100     Steven      King     SKING
# 1          101      Neena   Kochhar  NKOCHHAR

# %%
log_file['dt'] = pd.to_datetime(log_file['dt'])
log_file['month'] = log_file['dt'].dt.month_name()
log_file
# Out:
#      Log_ID         dt   dept  emp_id    activity       eqpt    month
# 0      1000 2022-01-07  Dept6     115    Cleaning        UPS  January
# 1      1001 2022-01-08  Dept4     105    Cleaning  Generator  January
# 2      1002 2022-01-09  Dept3     112  Inspection        CPU  January
# 3      1003 2022-01-10  Dept4     120  Inspection        UPS  January
# 4      1004 2022-01-11  Dept3     138    Checking    Battery  January
# ..      ...        ...    ...     ...         ...        ...      ...
# 360    1360 2023-01-02  Dept2     122      Repair         AC  January
# 361    1361 2023-01-03  Dept4     116    Checking     Server  January
# 362    1362 2023-01-04  Dept4     110    Checking        CPU  January
# 363    1363 2023-01-05  Dept4     102  Inspection         AC  January
# 364    1364 2023-01-06  Dept3     128    Cleaning         AC  January
#
# [365 rows x 7 columns]

# %%
ques6 = log_file.merge(employee,left_on = 'emp_id',right_on = 'EMPLOYEE_ID')

# %%
# Out:
# activity   Checking  Cleaning  Inspection  Repair
# month
# April             3         9           7       2
# August            7         9           9       4
# December          5         4           7       5
# February          4         6           4      10
# January           6         9           7       5
# July              5         5          10       2
# June              4         5           8       9
# March             6         4           4      12
# May               4         7           6       8
# November          6         9           4       6
# October          11         3           5       5
# September         8         2          10       5

# %%
ques7 = ques6[ques6['month'].str.contains('January')]
ques7['emp_id'].value_counts().head(1)
# Out:
# 122    3
# Name: emp_id, dtype: int64

# %%
ques6['days']= ques6['dt'].dt.day_name()
ques6
# Out:
#      Log_ID         dt   dept  emp_id    activity       eqpt      month  \
# 0      1000 2022-01-07  Dept6     115    Cleaning        UPS    January
# 1      1038 2022-02-14  Dept2     115    Cleaning        Fan   February
# 2      1048 2022-02-24  Dept4     115      Repair        CPU   February
# 3      1114 2022-05-01  Dept1     115      Repair    Battery        May
# 4      1293 2022-10-27  Dept4     115    Checking        CPU    October
# ..      ...        ...    ...     ...         ...        ...        ...
# 290    1218 2022-08-13  Dept3     111    Cleaning  Generator     August
# 291    1238 2022-09-02  Dept4     111  Inspection         AC  September
# 292    1274 2022-10-08  Dept4     111    Checking        CPU    October
# 293    1343 2022-12-16  Dept1     111    Cleaning        UPS   December
# 294    1307 2022-11-10  Dept2     121  Inspection         AC   November
#
#      EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL      days
# 0            115  Alexander      Khoo     AKHOO    Friday
# 1            115  Alexander      Khoo     AKHOO    Monday
# 2            115  Alexander      Khoo     AKHOO  Thursday
# 3            115  Alexander      Khoo     AKHOO    Sunday
# 4            115  Alexander      Khoo     AKHOO  Thursday
# ..           ...        ...       ...       ...       ...
# 290          111     Ismael   Sciarra  ISCIARRA  Saturday
# 291          111     Ismael   Sciarra  ISCIARRA    Friday
# 292          111     Ismael   Sciarra  ISCIARRA  Saturday
# 293          111     Ismael   Sciarra  ISCIARRA    Friday
# 294          121        NaN     Fripp    AFRIPP  Thursday
#
# [295 rows x 12 columns]

# %%
ques8 = ques6[ques6['days'].isin(['Saturday','Sunday'])]
ques8.groupby('emp_id')['activity'].count().sort_values(ascending = False).head(1)
# Out:
# emp_id
# 109    5
# Name: activity, dtype: int64

# %%
ques6[~(ques6['days'].isin(['Saturday','Sunday']))]['activity'].value_counts().head(1)
# Out:
# Inspection    62
# Name: activity, dtype: int64

# %%
ques9.groupby(['days','activity'])['emp_id'].count().reset_index().sort_values(by = 'emp_id',ascending = False).drop_duplicates(subset = 'days',keep='first').sort_values(by = 'days')
# Out:
#          days    activity  emp_id
# 2      Friday  Inspection      15
# 7      Monday      Repair      12
# 10   Thursday  Inspection      14
# 14    Tuesday  Inspection      13
# 16  Wednesday    Checking      13

# %%
ques6.pivot_table(index = 'days',columns = 'activity',aggfunc = 'count')['emp_id']
# Out:
# activity   Checking  Cleaning  Inspection  Repair
# days
# Friday            7        15          15       8
# Monday            9         9          11      12
# Saturday          9         8           6      11
# Sunday           11         9          13      11
# Thursday          8        14          14      11
# Tuesday          12         8          13      11
# Wednesday        13         9           9       9

# %% [markdown]
# ### `Q-11`:
#
# 1. There are missing value in first name of employee. Fill it using email and last name field.
#
# > E.g- `email` -> JMURMAN and `last_name` -> 'Urman' -> so make it's first name as 'JM', Sort of (Email- lastname).
#
# > Email is constructed from initials of first name concate with lastname. Your Task is to fill first name initials in missing data.
#
# 2. You can see email field don't have any domain name. Change this to full email addreess with domain as 'campusx.com'.
# E.g- Email field -> `JMURMAN`  result -> `JMURMAN@CAMPUSX.COM`
#
# 3. Show Full Name of all the employees whose name starts with 'A' and has done any of these activity ['Incpection', 'Cleaning', 'Checking]

# %%
# code here
employee[employee['FIRST_NAME'].isnull()].apply(lambda x:x[''])
# Out:
#     EMPLOYEE_ID FIRST_NAME LAST_NAME    EMAIL
# 12          112        NaN     Urman  JMURMAN
# 21          121        NaN     Fripp   AFRIPP
# 32          132        NaN     Olson  TJOLSON

# %%
fill_values= employee[employee['FIRST_NAME'].isnull()].apply(lambda ele:ele['LAST_NAME'][0] + ele['EMAIL'][0],axis = 1)

# %%
employee['FIRST_NAME'].fillna(fill_values,inplace = True)

# %%
employee['EMAIL'] = employee['EMAIL'] + '@campusx.com'

# %%
employee[employee['FIRST_NAME'].str.startswith('A')]
# Out:
#     EMPLOYEE_ID FIRST_NAME LAST_NAME                EMAIL
# 3           103  Alexander    Hunold  AHUNOLD@campusx.com
# 15          115  Alexander      Khoo    AKHOO@campusx.com

# %%
merge_df = log_file.merge(employee,left_on = 'emp_id',right_on = 'EMPLOYEE_ID')

# %%
merge_df[(merge_df['FIRST_NAME'].str.startswith('A')) & (merge_df['activity'].isin(['Incpection', 'Cleaning', 'Checking']))]
# Out:
#      Log_ID         dt   dept  emp_id  activity     eqpt     month  \
# 0      1000 2022-01-07  Dept6     115  Cleaning      UPS   January
# 1      1038 2022-02-14  Dept2     115  Cleaning      Fan  February
# 4      1293 2022-10-27  Dept4     115  Checking      CPU   October
# 5      1322 2022-11-25  Dept2     115  Cleaning      Fan  November
# 7      1332 2022-12-05  Dept3     115  Checking      UPS  December
# 235    1093 2022-04-10  Dept2     103  Checking       AC     April
# 237    1224 2022-08-19  Dept1     103  Cleaning       AC    August
# 239    1294 2022-10-28  Dept6     103  Checking  Battery   October
#
#      EMPLOYEE_ID FIRST_NAME LAST_NAME                EMAIL
# 0            115  Alexander      Khoo    AKHOO@campusx.com
# 1            115  Alexander      Khoo    AKHOO@campusx.com
# 4            115  Alexander      Khoo    AKHOO@campusx.com
# 5            115  Alexander      Khoo    AKHOO@campusx.com
# 7            115  Alexander      Khoo    AKHOO@campusx.com
# 235          103  Alexander    Hunold  AHUNOLD@campusx.com
# 237          103  Alexander    Hunold  AHUNOLD@campusx.com
# 239          103  Alexander    Hunold  AHUNOLD@campusx.com
