# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

plt.style.use('fast')

# %% [markdown]
# ## `Problem 1 to 5`:
#
# Dataset link: https://tinyurl.com/2fe6vz4u
#
# **Add a label to every axis and add a proper title for the charts. Also add proper labels if there are multiple representations.** Then, you can customize it as your wish.
#
# ### **`Problem-1:`** Draw a line plot of which, the x-axis is the "Year" and the y-axis is sum of "PM2.5" of two countries Iran and China.

# %%
# code here
df = pd.read_csv('https://tinyurl.com/2fe6vz4u')
df.head()
# Out:
#    Unnamed: 0  Position Country  City/Town  Year  PM2.5 Temporal coverage  \
# 0           0         1   India     Kanpur  2016    173              >75%
# 1           1         2   India  Faridabad  2016    172              >75%
# 2           2         3   India       Gaya  2016    149        50% -< 75%
# 3           3         4   India   Varanasi  2016    146              >75%
# 4           4         5   India      Patna  2016    144              >75%
#
#    PM10 Temporal coverage.1  Database version (year)
# 0   319                 NaN                     2018
# 1   316                 NaN                     2018
# 2   275                 NaN                     2018
# 3   260                 NaN                     2018
# 4   266                 NaN                     2018

# %%
df_iran = df[df['Country'] == 'Iran'].groupby('Year')['PM2.5'].sum()
df_india = df[df['Country'] == 'India'].groupby('Year')['PM2.5'].sum()

# %%
plt.plot(df_iran.index,df_iran.values,label = 'Iran',linestyle= 'solid')
plt.plot(df_india.index,df_india.values,label = 'India',linestyle = 'dashdot')
# plt.style.use('fivethirtyeight')

plt.title('PM2.5 comparison between India and Iran')
plt.xlabel('Year')
plt.ylabel('PM2.5 Values')
plt.xticks(df['Year'].sort_values())
plt.legend()
# plt.grid()
plt.show()

# %%
iran_series = df.query('Country == "Iran"').groupby('Year')['PM2.5'].sum()
china_series = df.query('Country == "China"').groupby('Year')['PM2.5'].sum()

# %%
plt.plot(iran_series.index,iran_series.values,label='Iran',linestyle='dashed')
plt.plot(china_series.index,china_series.values,label='China',linestyle='dotted',color='red')
plt.xlabel('Year')
plt.ylabel('PM2.5')
plt.title('PM2.5 Over the years')
plt.xticks(df['Year'].value_counts().index)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### **`Problem-2:`** Draw a histogram of the  column "PM10" of which the y-axis represents the probability (see the documentation how to draw the probability).

# %%
df.head(2)
# Out:
#    Unnamed: 0  Position Country  City/Town  Year  PM2.5 Temporal coverage  \
# 0           0         1   India     Kanpur  2016    173              >75%
# 1           1         2   India  Faridabad  2016    172              >75%
#
#    PM10 Temporal coverage.1  Database version (year)
# 0   319                 NaN                     2018
# 1   316                 NaN                     2018

# %%
plt.hist(df['PM10'],density = True,color = 'Green',bins = 50,alpha = 0.6)
plt.title('Histogram of PM10')
plt.xlabel('PM10')
plt.ylabel('Probability')
# plt.grid()
plt.show()

# %%
# code here
plt.hist(df['PM10'],density=True,bins=50,facecolor='green',alpha=0.6)
plt.xlabel('Bins')
plt.ylabel('Probability')
plt.title('Histogram of PM10')
plt.grid()
plt.show()

# %% [markdown]
# ### **`Problem-3:`** Draw a scatter plot where x-axis represents "PM2.5" and y-axis represents "PM10" for two countries Poland and Chile.

# %%
poland_series = df.query('Country == "Poland"')
Chile_series = df.query('Country == "Chile"')

# %%
poland_series
# Out:
#      Unnamed: 0  Position Country             City/Town  Year  PM2.5  \
# 370         370       371  Poland                 Godów  2016     33
# 371         371       372  Poland               Pleszew  2016     33
# 392         392       393  Poland               Gliwice  2016     32
# 404         404       405  Poland                Kraków  2016     31
# 405         405       406  Poland             Nowy Sącz  2016     31
# 425         425       426  Poland              Katowice  2016     30
# 446         446       447  Poland               Bochnia  2016     29
# 447         447       448  Poland  Piotrków Trybunalski  2016     29
# 448         448       449  Poland                  Żory  2016     29
# 471         471       472  Poland         Bielsko-Biała  2016     28
# 472         472       473  Poland       Tarnowskie Góry  2016     28
# 492         492       493  Poland                 Chełm  2015     27
# 493         493       494  Poland                Kalisz  2016     27
# 494         494       495  Poland      Kędzierzyn-Koźle  2016     27
# 495         495       496  Poland                Lublin  2016     27
# 496         496       497  Poland               Siedlce  2016     27
# 497         497       498  Poland             Trzebinia  2016     27
#
#     Temporal coverage  PM10 Temporal coverage.1  Database version (year)
# 370              >75%    43                >75%                     2018
# 371              >75%    38                >75%                     2018
# 392              >75%    46                >75%                     2018
# 404              >75%    42                >75%                     2018
# 405              >75%    41                >75%                     2018
# 425              >75%    41                >75%                     2018
# 446              >75%    35                >75%                     2018
# 447              >75%    38                >75%                     2018
# 448              >75%    42                >75%                     2018
# 471              >75%    36                >75%                     2018
# 472              >75%    38                >75%                     2018
# 492              >75%    35                >75%                     2018
# 493              >75%    33                >75%                     2018
# 494              >75%    32                >75%                     2018
# 495              >75%    31                >75%                     2018
# 496              >75%    29                >75%                     2018
# 497              >75%    35                >75%                     2018

# %%
plt.scatter(poland_series['PM2.5'],poland_series['PM10'],label = 'Poland',color = 'Green',marker="+")
plt.scatter(Chile_series['PM2.5'],Chile_series['PM10'],label = 'Chile',color = 'Red')
plt.legend()
plt.title('Comparison of PM2.5 vs PM10')
plt.xlabel('PM2.5')
plt.ylabel('PM10')
# Out:
# Text(0, 0.5, 'PM10')

# %%
# code here
chile_df = df.query("Country == 'Chile'")
poland_df = df.query("Country == 'Poland'")

# %%
plt.scatter(chile_df['PM2.5'],chile_df['PM10'],marker="+",color='red',label='Chile')
plt.scatter(poland_df['PM2.5'],poland_df['PM10'],marker="D",color='black',label='Poland')
plt.xlabel('PM2.5')
plt.ylabel('PM10')
plt.title('PM2.5 Vs PM10 for Chile and Poland')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### **`Problem-4:`** Draw a pie chart of top 5 most frequent countries.

# %%
df.head(2)
# Out:
#    Unnamed: 0  Position Country  City/Town  Year  PM2.5 Temporal coverage  \
# 0           0         1   India     Kanpur  2016    173              >75%
# 1           1         2   India  Faridabad  2016    172              >75%
#
#    PM10 Temporal coverage.1  Database version (year)
# 0   319                 NaN                     2018
# 1   316                 NaN                     2018

# %%
frequency = df['Country'].value_counts().head(5)

# %%
frequency.values
# Out:
# array([283,  43,  32,  19,  17], dtype=int64)

# %%
plt.pie(frequency.values,labels = frequency.index,autopct='%0.1f%%')
plt.show()

# %%
# code here
freq_ser = df['Country'].value_counts().head()

# %%
plt.pie(freq_ser,labels=freq_ser.index,autopct='%0.1f%%')
plt.show()

# %% [markdown]
# ### **`Problem-5:`** Draw a bar chart which represents the counts of top 5 most frequent countries.

# %%
# code here
plt.bar(freq_ser.index,freq_ser)
plt.xlabel('Country')
plt.ylabel('Frequency Count')
plt.show()

# %% [markdown]
# ##`Problem 6-10`
# Data Set - https://docs.google.com/spreadsheets/d/e/2PACX-1vTJh6X4_mqixWsfK9mgkllGQkKYW9Wj9kOIMGY2uYsWeS8n5np87DO-SDGQWJ1HXEnxiOVFVzYFYEcR/pub?gid=558678488&single=true&output=csv
#
# This is a Sales data of any company in a Year.
#
#
# ###`Problem-6`
# Show a line plot of Total Profit for each month with below styling.
# * Dotted Line
# * Line Color Blue
# * Show Legend at top left
# * Circle Marker

# %%
data = pd.read_csv(' https://docs.google.com/spreadsheets/d/e/2PACX-1vTJh6X4_mqixWsfK9mgkllGQkKYW9Wj9kOIMGY2uYsWeS8n5np87DO-SDGQWJ1HXEnxiOVFVzYFYEcR/pub?gid=558678488&single=true&output=csv')

# %%
data.head(1)
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000

# %%
plt.plot(data['month_number'],data['total_profit'],linestyle = 'dotted',color = 'Blue',label = 'total_profit',marker = 'o',markersize = 15)
plt.legend(loc='upper left')
plt.title('Comparison of total profit month wise')
plt.xlabel('Months')
plt.ylabel('Total Profit')
plt.show()

# %%
# code here
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vTJh6X4_mqixWsfK9mgkllGQkKYW9Wj9kOIMGY2uYsWeS8n5np87DO-SDGQWJ1HXEnxiOVFVzYFYEcR/pub?gid=558678488&single=true&output=csv')
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 0          1500        21100        211000
# 1          1200        18330        183300
# 2          1340        22470        224700
# 3          1130        22270        222700
# 4          1740        20960        209600
# 5          1555        20140        201400
# 6          1120        29550        295500
# 7          1400        36140        361400
# 8          1780        23400        234000
# 9          1890        26670        266700
# 10         2100        41280        412800
# 11         1760        30020        300200

# %%
plt.plot(df['month_number'],df['total_profit'],label='Month on month Profit',color='b',marker='o',linestyle='dotted')
plt.xlabel('Month')
plt.ylabel('Total Profit')
plt.title('Company sales profit')
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# ###`Problem-7`
# Show sales of each product in march month as pie chart.
# * Show Percentage value
# * Give Title "Sales in March"
# * Explode ToothPaste with shadow

# %%
march_series = data[data['month_number'] == 3]
final_series = march_series.squeeze()

# %%
labels = final_series.index[1:-2]
values = final_series.values[1:-2]

# %%
plt.pie(values,labels= labels,autopct='%0.1f%%',shadow = True)
plt.title('Sales of each product in March')
plt.show()

# %%
# code here
labels = df[df['month_number'] == 3].iloc[:,1:7].stack().index.get_level_values(1)
values = df[df['month_number'] == 3].iloc[:,1:7].stack().values

# %%
labels
# Out:
# Index(['facecream', 'facewash', 'toothpaste', 'bathingsoap', 'shampoo',
#        'moisturizer'],
#       dtype='object')

# %%
plt.pie(values,labels=labels,autopct='%0.1f%%',explode=[0,0,0.1,0,0,0],shadow=True)
plt.title("Sales in March")
plt.show()

# %% [markdown]
# ###`Problem-8` Multiline Plot of all products sales.
# * Give different styes for each products
# * Add legend at top right

# %%
plt.plot(data['month_number'],data['toothpaste'], color = 'Red',label = 'Toothpaste',linestyle = 'solid',linewidth = 2.5)
plt.plot(data['month_number'],data['facewash'], color = 'Green',label = 'Facewash',linestyle = 'dashdot',linewidth= 3)
plt.plot(data['month_number'],data['facecream'], color = 'Blue',label = 'Facecream',linestyle = 'dotted',linewidth= 3.5)
plt.plot(data['month_number'],data['moisturizer'], color = 'Yellow',label = 'moisturizer',linestyle = 'solid',linewidth= 2.8)
plt.plot(data['month_number'],data['shampoo'], color = 'Pink',label = 'shampoo',linestyle = 'solid',linewidth= 2.8)
plt.plot(data['month_number'], data['bathingsoap'],   label = 'Bathing Soap',  linestyle='dashed', linewidth=2)
plt.legend()
plt.title('Sales of all products in all months')
plt.xlabel('Months')
plt.ylabel('Products')
plt.xticks(data['month_number'])
plt.show()

# %%
# code here
monthList  = df['month_number'].tolist()

plt.plot(monthList, df['facecream'],   label = 'Face cream', linestyle='dotted', marker='o', linewidth=3)
plt.plot(monthList, df['toothpaste'], label = 'Tooth Paste', marker='o', linewidth=3)
plt.plot(monthList, df['bathingsoap'], label = 'Bathing Soap', marker='o', linewidth=3)
plt.plot(monthList, df['shampoo'], label = 'Shampoo', linestyle='dashdot', linewidth=3)
plt.plot(monthList, df['moisturizer'], label = 'Moisturizer', marker='o', linewidth=3)
plt.plot(monthList, df['facewash'],   label = 'Face Wash',  linestyle='dashed', linewidth=2)


plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.legend(loc='upper right')
plt.xticks(monthList)
plt.title('Sales data')
plt.show()

# %% [markdown]
# ###`Problem-9` Show Quarter wise Sales data for all products as multi Bar chart.

# %%
data['month_number'] = pd.to_datetime(data['month_number'])

# %%
data
# Out:
#                     month_number  facecream  facewash  toothpaste  \
# 0  1970-01-01 00:00:00.000000001       2500      1500        5200
# 1  1970-01-01 00:00:00.000000002       2630      1200        5100
# 2  1970-01-01 00:00:00.000000003       2140      1340        4550
# 3  1970-01-01 00:00:00.000000004       3400      1130        5870
# 4  1970-01-01 00:00:00.000000005       3600      1740        4560
# 5  1970-01-01 00:00:00.000000006       2760      1555        4890
# 6  1970-01-01 00:00:00.000000007       2980      1120        4780
# 7  1970-01-01 00:00:00.000000008       3700      1400        5860
# 8  1970-01-01 00:00:00.000000009       3540      1780        6100
# 9  1970-01-01 00:00:00.000000010       1990      1890        8300
# 10 1970-01-01 00:00:00.000000011       2340      2100        7300
# 11 1970-01-01 00:00:00.000000012       2900      1760        7400
#
#     bathingsoap  shampoo  moisturizer  total_units  total_profit
# 0          9200     1200         1500        21100        211000
# 1          6100     2100         1200        18330        183300
# 2          9550     3550         1340        22470        224700
# 3          8870     1870         1130        22270        222700
# 4          7760     1560         1740        20960        209600
# 5          7490     1890         1555        20140        201400
# 6          8980     1780         1120        29550        295500
# 7          9960     2860         1400        36140        361400
# 8          8100     2100         1780        23400        234000
# 9         10300     2300         1890        26670        266700
# 10        13300     2400         2100        41280        412800
# 11        14400     1800         1760        30020        300200

# %%
# code here
df['date'] = pd.to_datetime(['2020-{}-01'.format(month) for month in df['month_number']])

# %%
final_df = df.groupby(df['date'].dt.quarter).sum()

# %%
final_df
# Out:
#       month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# date
# 1                6       7270      4040       14850        24850     6850
# 2               15       9760      4425       15320        24120     5320
# 3               24      10220      4300       16740        27040     6740
# 4               33       7230      5750       23000        38000     6500
#
#       moisturizer  total_units  total_profit
# date
# 1            4040        61900        619000
# 2            4425        63370        633700
# 3            4300        89090        890900
# 4            5750        97970        979700

# %%
i = -1
for col in final_df.columns[1:7]:
  plt.bar(final_df.index + i,final_df[col],width=0.15,label=col)
  i = i - 0.15

plt.xticks(final_df.index-1.4,final_df.index)
plt.xlabel('Product')
plt.ylabel('Sales')
plt.legend()
plt.show()

# %%
final_df.iloc[:,1:7]
# Out:
#       facecream  facewash  toothpaste  bathingsoap  shampoo  moisturizer
# date
# 1          7270      4040       14850        24850     6850         4040
# 2          9760      4425       15320        24120     5320         4425
# 3         10220      4300       16740        27040     6740         4300
# 4          7230      5750       23000        38000     6500         5750

# %% [markdown]
# ###`Problem-10` Plot Stacked Bar chart quarter wise for each product.

# %%
# code here
final_df
# Out:
#       month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# date
# 1                6       7270      4040       14850        24850     6850
# 2               15       9760      4425       15320        24120     5320
# 3               24      10220      4300       16740        27040     6740
# 4               33       7230      5750       23000        38000     6500
#
#       moisturizer  total_units  total_profit
# date
# 1            4040        61900        619000
# 2            4425        63370        633700
# 3            4300        89090        890900
# 4            5750        97970        979700

# %%
all_cols = []

for col in final_df.columns[1:7]:
  if len(all_cols) == 0:
    plt.bar(final_df.index,final_df[col],label=col)
  else:
    plt.bar(final_df.index,final_df[col],bottom=sum(all_cols),label=col)
  all_cols.append(final_df[col])

plt.xticks(final_df.index - 0.02, final_df.index)
plt.legend()
plt.show()

# %%
sum(all_cols)
# Out:
# date
# 1    61900
# 2    63370
# 3    69340
# 4    86230
# dtype: int64
